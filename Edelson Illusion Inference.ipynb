# %% [markdown]
# # Edelson Illusion Inference

# %% [markdown]
# # Things to Expand on in the Future

# %% [markdown]
# TODO: Edelson Illusion? (Both Pixel matching and conditioning on two "squares" being the same)
#
# Images rendered can be turned into actual Pillow images (as seen in the "Getting Started with Open3D" notebook). Worth a try to see if cropping/transforming them and comparing average pixel values works so I can condition on two spots on a checkerboard being the same.
#
# TODO: Replace Graphs w/ helper function calls
#
# TODO: Add Colormap to o3d Plot
#
# TODO: Experiment with different models
#
# TODO: Cleanup Code
#
# TODO: Make "threshold" condition based on image likelihood w/ itself
